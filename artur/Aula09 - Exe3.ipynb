# %% [markdown]
# ### Exercício 3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

caminhoArquivo = './Arquivos/company_sales_data.csv'

df = pd.read_csv(caminhoArquivo)

df.head(1)

listaMes = df['month_number'].to_list()
faceCream = df['facecream'].to_list()
faceWash = df['facewash'].to_list()
toothPaste = df['toothpaste'].to_list()
bathingSoap = df['bathingsoap'].to_list()
shampooSales = df['shampoo'].to_list()
moisturizerSales = df['moisturizer'].to_list()

# Gerar um gráfico de linhas para plotar cada variável descrita acima
# Tipo  de marcador = o | linewidth = 3

plt.plot(listaMes, faceCream, label = 'Face Cream', marker = 'o', linewidth = 3)
plt.plot(listaMes, faceWash, label = 'Face Wash', marker = 'o', linewidth = 3)
plt.plot(listaMes, toothPaste, label = 'Tooth Paste', marker = 'o', linewidth = 3)
plt.plot(listaMes, bathingSoap, label = 'Bathing Soap', marker = 'o', linewidth = 3)
plt.plot(listaMes, shampooSales, label = 'Shampoo', marker = 'o', linewidth = 3)
plt.plot(listaMes, moisturizerSales, label = 'Moisturizer', marker = 'o', linewidth = 3)


# Adicionando legendas ao gráfico
plt.ylabel('Sales unit number')
plt.xlabel('Month Number')
plt.legend(loc = 'upper left')

#Ajustando os rótulos do eixo
plt.xticks(listaMes)
plt.yticks([1000,2000,4000,6000,8000,10000,12000,14000,16000,18000])

# Título do gráfico
plt.title('Dados de Venda')

# Exibir o gráfico
plt.show()

# %% [markdown]
# ### Exercício 04

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

caminhoArquivo = './Arquivos/company_sales_data.csv'

df = pd.read_csv(caminhoArquivo)

df.head(1)

# Gerar listas
listaMes = df['month_number'].to_list()
VendasPasta = df['toothpaste'].to_list()

# Criar o gráfico de dispersão com seaborn
sns.scatterplot(x = listaMes, y = VendasPasta, label = 'Vendas pasta de dente', c = 'red')

plt.title('Gráfico Dispersão')
plt.xlabel('Mês')
plt.ylabel('Vendas')
plt.grid(True, linewidth = 0.5, linestyle = '--')
plt.xticks(listaMes)
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ([<matplotlib.axis.XTick at 0x17f7f9eef50>,
# ...
#  [Text(1, 0, '1'),
#   Text(2, 0, '2'),
#   Text(3, 0, '3'),
#   Text(4, 0, '4'),
#   Text(5, 0, '5'),
#   Text(6, 0, '6'),
#   Text(7, 0, '7'),
#   Text(8, 0, '8'),
#   Text(9, 0, '9'),
#   Text(10, 0, '10'),
#   Text(11, 0, '11'),
#   Text(12, 0, '12')])

# %% [markdown]
# ### Exercício 5

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

caminhoArquivo = './Arquivos/company_sales_data.csv'

df = pd.read_csv(caminhoArquivo)

# Mostrar cabeçalho com uma linha
df.head(1)

# Gerar listas
cremeFacial = df['facecream'].to_list()
sabaoFacial = df['facewash'].to_list()
listaMes = df['month_number'].to_list()

sns.color_palette("rocket", as_cmap=True)
sns.barplot(x = listaMes, y = cremeFacial, label = 'Creme Facial')
sns.barplot(x = listaMes, y = sabaoFacial, label = 'Sabão Facial')
# Out:
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# c:\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
